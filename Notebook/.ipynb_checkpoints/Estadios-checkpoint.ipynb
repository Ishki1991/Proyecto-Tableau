# %%
import pandas as pd

# %%
estadios = pd.read_excel("datos/Estadios.xlsx")
estadios.head(10)
# Out:
#                    Estadio                 Ciudad   Año  Aforo  \
# 0                 Camp Nou              Barcelona  1957  99354
# 1        Santiago Bernabéu                 Madrid  1947  99354
# 2    Estadio Metropolitano                 Madrid  2017  99354
# 3        Benito Villamarín                Sevilla  1929  99354
# 4  Olímpico Lluís Companys              Barcelona  1929  99354
# 5               La Cartuja   Santiponce y Sevilla  1997  99354
# 6                San Mamés                 Bilbao  2013  99354
# 7                 Mestalla               Valencia  1923  99354
# 8    Ramón Sánchez-Pizjuán                Sevilla  1958  99354
# 9             RCDE Stadium  Cornellà de Llobregat  2009  99354
#
#                 Equipo
# 0      F. C. Barcelona
# 1    Real Madrid C. F.
# 2   Atlético de Madrid
# 3  Real Betis Balompié
# 4           Desocupado
# 5   Selección española
# 6        Athletic Club
# 7       Valencia C. F.
# 8           Sevilla FC
# 9         RCD Espanyol

# %%
estadios.to_csv("data/df_estadios.csv", index=False)
